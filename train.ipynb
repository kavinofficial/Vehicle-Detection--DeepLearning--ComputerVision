# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 870.4/870.4 kB 24.1 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
model = YOLO("yolov8n.pt")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 127MB/s]

# %%
data_config = "/content/drive/MyDrive/indianVehicle/data.yaml"

# %%
from google.colab import files

# Download the best model weights
files.download('/content/vehicleDetector/train3/test4.avi')

# %%
result = model.train(data = data_config , epochs = 90 , imgsz=640 , save=True , save_period=1 , project="vehicleDetector")
# Out:
# Ultralytics 8.3.14 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
model.val(data = data_config)
# Out:
# Ultralytics 8.3.14 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 186 layers, 2,685,538 parameters, 0 gradients, 6.8 GFLOPs
# val: Scanning /content/drive/MyDrive/indianVehicle/valid/labels.cache... 900 images, 0 backgrounds, 0 corrupt: 100%|██████████| 900/900 [00:00<?, ?it/s]
# val: WARNING ⚠️ /content/drive/MyDrive/indianVehicle/valid/images/car55.jpg: corrupt JPEG restored and saved
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 57/57 [00:24<00:00,  2.37it/s]
#                    all        900       1150      0.972      0.949      0.981      0.917
#                    car        182        201      0.949      0.923      0.957      0.931
#             threewheel        167        227      0.991      0.957      0.992      0.936
#                    bus        162        185      0.986      0.978      0.992      0.961
# ...

# %%
pred = model.predict(source="/content/drive/MyDrive/test4.mp4" , show = True , save = True)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
